# %% [markdown]
# This is an exploratory notebook for the stanford contracts database. They have worked with the EDGAR database to make it machine readable, so I am going to play around with what is in the folder just to see if it could be useful to this project

# %%
import os
import polars as pl
import re
import PyPDF2
import textwrap
from rapidfuzz import process, fuzz

# %%
#starting with one quarter of one year for size and so we don't have to traverse the data directory
data_pathway = '/Users/georgia/Desktop/stanford_law/padelson/production_contracts/2000/Q1'

#list all files in the data pathway
files = os.listdir(data_pathway)

#print the number of files
print(len(files))
# Out:
# 173

# %%
#see the filetypes in this folder so we know how to load them in 
file_extensions = set()
for f in files:
    _, ext = os.path.splitext(f)
    file_extensions.add(ext.lower())

print("File extensions in folder:", file_extensions)
# Out:
# File extensions in folder: {'', '.pdf', '.html'}

# %%
metadata = pl.read_csv('/Users/georgia/Desktop/stanford_law/stanford_metadata.csv')

# %%
# Display one full row from the metadata DataFrame in a nice, readable way
import pprint

row = metadata.row(0)
columns = metadata.columns
row_dict = dict(zip(columns, row))
pprint.pprint(row_dict, sort_dicts=False)
# Out:
# {'': 0,
#  'year': 2000,
#  'cik': 1001136,
#  'company.name': 'STOCKWALK COM GROUP INC',
#  'form.type': '10-Q',
#  'date.filed': '2000-02-14',
#  'edgar.link': 'edgar/data/1001136/0000950124-00-000624.txt',
#  'quarter': 1,
#  'index.link': 'edgar/data/1001136/0000950124-00-000624/000095012400000624-index.html',
#  'contract.link': '/Archives/edgar/data/1001136/000095012400000624/0000950124-00-000624-d2.html',
#  'exhibit': 'EX-2.1',
#  'description': 'asset purchase agreement',
#  'exhibit_lead': 'EX-2',
#  'contract': '/Archives/edgar/data/1001136/000095012400000624/0000950124-00-000624-d2.html',
#  'type_label': 'LABEL_4',
#  'type_score': 0.9999955892562866,
#  'amend': 0,
#  'restate': 0,
#  'joinder': 0,
#  'termination': 0,
#  'parties': "['stockwalkcom inc', 'stockwalkcom group inc', 'stockwalk com "
#             "group inc', 'william yang', 'm-one investment securities inc']",
#  'agreement_type': 'purchase&ma',
#  'parties_cleaned': "['m-one investment securities inc', 'william yang', "
#                     "'stockwalkcom group inc', 'stockwalkcom inc', 'stockwalk "
#                     "com group inc']",
#  'master_parties': "['stockwalk com group inc', 'william yang', 'stockwalkcom "
#                    "inc', 'm-one investment securities inc']"}

# %%
def read_htm_file(filepath):
    """Read an .htm file and return its text content (stripped of HTML tags)."""
    with open(filepath, 'r', encoding='utf-8', errors='ignore') as f:
        html = f.read()
    # Remove HTML tags for plain text extraction
    text = re.sub('<[^<]+?>', '', html)
    return text.strip()

# %%
def read_pdf_file(filepath):
    """Read a .pdf file and return its text content."""
    text = ""
    with open(filepath, 'rb') as f:
        reader = PyPDF2.PdfReader(f)
        for page in reader.pages:
            page_text = page.extract_text()
            if page_text:
                text += page_text
    return text.strip()

# %%
#get the contracts themselves into a dataframe
records = []
for fname in files:
    fpath = os.path.join(data_pathway, fname)
    ext = os.path.splitext(fname)[1].lower()
    if ext in ['.htm', '.html']:
        try:
            text = read_htm_file(fpath)
        except Exception as e:
            text = f"[ERROR reading HTML: {e}]"
    elif ext == '.pdf':
        try:
            text = read_pdf_file(fpath)
        except Exception as e:
            text = f"[ERROR reading PDF: {e}]"
    else:
        text = "[UNSUPPORTED FILETYPE]"
    records.append({'title': fname, 'text': text})

# Create polars DataFrame and explicitly set column dtypes to avoid 'str' header confusion
contracts_df = pl.DataFrame(records, schema={"title": pl.String, "text": pl.String})

# %%
contracts_df
# Out:
# shape: (173, 2)
# ┌─────────────────────────────────┬─────────────────────────────────┐
# │ title                           ┆ text                            │
# │ ---                             ┆ ---                             │
# │ str                             ┆ str                             │
# ╞═════════════════════════════════╪═════════════════════════════════╡
# │ 823534..000082353400000004..00… ┆ EX10.14                         │
# │                                 ┆                                 │
# │                                 ┆                                 │
# │                                 ┆                                 │
# │                                 ┆                                 │
# │                                 ┆ EXHIBIT 10.14                   │
# │                                 ┆ EMPL…                           │
# │ 39273..000003927300000005..000… ┆ EXHIBIT 10.1                    │
# │                                 ┆                                 │
# │                                 ┆ &nbsp;&nbsp;&nbs…               │
# │ 929455..000092945500000002..00… ┆ EXHIBIT 10.20                   │
# │                                 ┆ NEITHER THIS WAR…               │
# │ 716399..000091205700004404..00… ┆ Prepared by MERRILL CORPORATIO… │
# │ 731190..000095013200000238..00… ┆ FORM OF BONUS AGREEMENT         │
# │                                 ┆                                 │
# │                                 ┆                                 │
# │                                 ┆   Ex…                           │
# │ …                               ┆ …                               │
# │ 1089786..000095014400001606..0… ┆ Lanier Worldwide, Inc. / Exhib… │
# │ 731190..000095013200000238..00… ┆ PHILIP STRAWBRIDGE CONTRACT TE… │
# │ 912093..000091209300000004..00… ┆ Merger                          │
# │                                 ┆                                 │
# │                                 ┆                                 │
# │                                 ┆                                 │
# │                                 ┆                                 │
# │                                 ┆                                 │
# │                                 ┆ AGREEMENT AND PLAN…             │
# │ 1026869..000102686900000003..0… ┆ PARTNERSHIP TERMINATION AGREEM… │
# │ 731190..000095013200000238..00… ┆ IT CORPORATION RESTORATION PLA… │
# └─────────────────────────────────┴─────────────────────────────────┘

# %%
# Select a row index to display (e.g., the first row)
row_idx = 0

# Get the title and text
row = contracts_df.row(row_idx)
title, text = row[0], row[1]

print(f"Title: {title}\n")
print("Text:\n")
print(textwrap.fill(text, width=100))
# Out:
# Title: 823534..000082353400000004..0000823534-00-000004-d7.html
#
# Text:
#
# EX10.14     EXHIBIT 10.14 EMPLOYMENT AGREEMENT   MEMORANDUM OF AGREEMENT entered into at Stamford,
# Connecticut, this 1st day of October, 1999.     BY AND BETWEEN:  REPAP ENTERPRISES INC., a company
# duly incorporated under the laws of Canada, having its executive offices at 300 Atlantic Street,
# Suite 200, Stamford, Connecticut, 06901, herein acting and represented by Stephen C. Larson, duly
# authorized to act hereunder for the purposes of the present Agreement as he so declares;   &nbsp;
# &nbsp;   &nbsp;  (hereinafter the "Corporation")   &nbsp;  &nbsp;   AND  TERRY W. McBRIDE, business
# executive, having his address for the purposes of the present Agreement at 189 Brookwood Lane, New
# Canaan, Connecticut 06840   &nbsp;  &nbsp;   &nbsp;  (hereinafter the "Executive")
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;THE PARTIES DECLARE AS FOLLOWS: &nbsp;&nbsp;&nbsp;&nbsp;&nbsp
# other benefits herein mentioned; or (d)&#9;a requirement that the Executive perform his duties in a
# municipality other than the municipality in which the Executive resides at the date of this
# Agreement and other than the Region surrounding Stamford, Connecticut;     "Governmental Body" shall
# mean:     (a)&#9;any domestic or foreign national, federal, provincial, state, municipal or other
# government body; (b)&#9;any subdivision, ministry, department, secretariat, bureau, agency,
# commission, board, instrumentality or authority of any of the foregoing governments or bodies;
# (c)&#9;any quasi-governmental or private body exercising any regulatory, expropriation or taxing
# authority under or for the account of any of the foregoing governments or bodies; or (d)&#9;any
# domestic or foreign judicial, quasi-judicial, arbitration or administrative court, grand jury,
# commission, board or panel.     "Incapacity" shall mean any medical condition whatsoever, which
# leads to the Executive's absence from job function for a continuous period of six (6) months,
# without the Executive being able to resume functions on a full time basis at the expiration of such
# period and unsuccessful attempts to return to work for periods under fifteen (15) days shall not
# interrupt the calculation of the said six (6) month period. "Person" shall mean any individual or
# other entity possessed of juridical personality, including, without limitation, a corporation,
# company, cooperative, partnership, trust, unincorporated association or Governmental Body; and
# pronouns when they refer to a Person shall have a similarly extended meaning.

# %% [markdown]
# ## Combining meta and full data

# %%
# To combine contracts_df and metadata, extract the substring after the second '..' in contracts_df['title'],
# then check if this substring appears anywhere in metadata['contract'].
# We'll create a new column in contracts_df for this extracted sequence, then perform a join based on substring matching.

def extract_short_title(s):
    # Extract substring after the second occurrence of '..'
    parts = s.split('..', 2)
    if len(parts) > 2:
        return parts[2]
    return ""

# %%
extract_short_title(contracts_df['title'][0])
# Out:
# '0000823534-00-000004-d7.html'

# %%
contracts_df = contracts_df.with_columns(
    pl.Series([extract_short_title(s) for s in contracts_df["title"]]).alias("short_title")
)

# %%
def find_matching_contract(short_title, contracts):
    for idx, contract in enumerate(contracts):
        if short_title and short_title in contract:
            return idx
    return None

# %%
# Get the list of contracts from metadata
metadata_contracts = metadata["contract"].to_list()

def match_titles(metadata_contracts):
    # For each row in contracts_df, find the matching index in metadata
    matching_indices = [
        find_matching_contract(short_title, metadata_contracts)
        for short_title in contracts_df["short_title"]
    ]
        
    # Track if any warning was printed
    any_warning = False
    for title, idx in zip(contracts_df["title"], matching_indices):
        if idx is None:
            print(f"WARNING: No matching index found for title: {title}")
            any_warning = True
        elif isinstance(idx, list) and len(idx) != 1:
            print(f"WARNING: Multiple ({len(idx)}) matching indices found for title: {title} -> {idx}")
            any_warning = True
        elif isinstance(idx, list) and len(idx) == 1:
            pass  # exactly one match, all good
        elif isinstance(idx, int):
            pass  # exactly one match, all good
        else:
            print(f"WARNING: Unexpected matching index for title: {title} -> {idx}")
            any_warning = True

    if not any_warning:
        print("All contract titles successfully matched to metadata entries!")
    
    return matching_indices

# %%
#get rid of the .ipynb_checkpoints row of the contracts_df
contracts_df = contracts_df.filter(pl.col("title") != ".ipynb_checkpoints")

#get rid of the .ipynb_checkpoints row of the metadata
metadata = metadata.filter(pl.col("contract") != ".ipynb_checkpoints")

# %%
# Use match_titles to get matching indices
matching_indices = match_titles(metadata_contracts)

# Build a DataFrame with the matched metadata rows (or None)
matched_metadata = metadata[matching_indices].with_columns(
    pl.Series(matching_indices).alias("metadata_idx")
)
# Out:
# All contract titles successfully matched to metadata entries!

# %%
# Concatenate contracts_df and matched_metadata horizontally
df_combined = contracts_df.with_columns(
    matched_metadata
)

# %%
df_combined
# Out:
# shape: (172, 28)
# ┌────────────┬────────────┬────────────┬─────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ title      ┆ text       ┆ short_titl ┆     ┆ … ┆ agreement_ ┆ parties_cl ┆ master_pa ┆ metadata_ │
# │ ---        ┆ ---        ┆ e          ┆ --- ┆   ┆ type       ┆ eaned      ┆ rties     ┆ idx       │
# │ str        ┆ str        ┆ ---        ┆ i64 ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │            ┆            ┆ str        ┆     ┆   ┆ str        ┆ str        ┆ str       ┆ i64       │
# ╞════════════╪════════════╪════════════╪═════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ 823534..00 ┆ EX10.14    ┆ 0000823534 ┆ 145 ┆ … ┆ employment ┆ ['repap    ┆ ['repap   ┆ 145       │
# │ 0082353400 ┆            ┆ -00-000004 ┆     ┆   ┆            ┆ enterprise ┆ enterpris ┆           │
# │ 000004..00 ┆            ┆ -d7.html   ┆     ┆   ┆            ┆ s inc',    ┆ es inc',  ┆           │
# │ …          ┆            ┆            ┆     ┆   ┆            ┆ 'ste…      ┆ 'ste…     ┆           │
# │            ┆            ┆            ┆     ┆   ┆            ┆            ┆           ┆           │
# │            ┆ EXHIBIT    ┆            ┆     ┆   ┆            ┆            ┆           ┆           │
# │            ┆ 10.14      ┆            ┆     ┆   ┆            ┆            ┆           ┆           │
# │            ┆ EMPL…      ┆            ┆     ┆   ┆            ┆            ┆           ┆           │
# │ 39273..000 ┆ EXHIBIT    ┆ 0000039273 ┆ 67  ┆ … ┆ security   ┆ ['w andb', ┆ ['w       ┆ 67        │
# │ 0039273000 ┆ 10.1       ┆ -00-000005 ┆     ┆   ┆            ┆ 'conwell   ┆ andb',    ┆           │
# │ 00005..000 ┆            ┆ -d2.html   ┆     ┆   ┆            ┆ corporatio ┆ 'conwell  ┆           │
# │ …          ┆ &nbsp;&nbs ┆            ┆     ┆   ┆            ┆ …          ┆ corporati ┆           │
# │            ┆ p;&nbs…    ┆            ┆     ┆   ┆            ┆            ┆ o…        ┆           │
# │ 929455..00 ┆ EXHIBIT    ┆ 0000929455 ┆ 175 ┆ … ┆ na         ┆ ['clubcorp ┆ ['clubcor ┆ 175       │
# │ 0092945500 ┆ 10.20      ┆ -00-000002 ┆     ┆   ┆            ┆ inc']      ┆ p inc']   ┆           │
# │ 000002..00 ┆ NEITHER    ┆ -d14.pdf   ┆     ┆   ┆            ┆            ┆           ┆           │
# │ …          ┆ THIS WAR…  ┆            ┆     ┆   ┆            ┆            ┆           ┆           │
# │ 716399..00 ┆ Prepared   ┆ 0000912057 ┆ 78  ┆ … ┆ shareholde ┆ ['calendar ┆ ['calenda ┆ 78        │
# │ 0091205700 ┆ by MERRILL ┆ -00-004404 ┆     ┆   ┆ r          ┆ capital    ┆ r capital ┆           │
# │ 004404..00 ┆ CORPORATIO ┆ -d2.html   ┆     ┆   ┆            ┆ inc',      ┆ inc',     ┆           │
# │ …          ┆ …          ┆            ┆     ┆   ┆            ┆ 'entr…     ┆ 'entr…    ┆           │
# │ 731190..00 ┆ FORM OF    ┆ 0000950132 ┆ 107 ┆ … ┆ employment ┆ ['the it   ┆ ['it      ┆ 107       │
# │ 0095013200 ┆ BONUS      ┆ -00-000238 ┆     ┆   ┆            ┆ group      ┆ group     ┆           │
# │ 000238..00 ┆ AGREEMENT  ┆ -d12.html  ┆     ┆   ┆            ┆ inc', 'it  ┆ inc']     ┆           │
# │ …          ┆            ┆            ┆     ┆   ┆            ┆ group…     ┆           ┆           │
# │            ┆            ┆            ┆     ┆   ┆            ┆            ┆           ┆           │
# │            ┆   Ex…      ┆            ┆     ┆   ┆            ┆            ┆           ┆           │
# │ …          ┆ …          ┆ …          ┆ …   ┆ … ┆ …          ┆ …          ┆ …         ┆ …         │
# │ 1089786..0 ┆ Lanier     ┆ 0000950144 ┆ 29  ┆ … ┆ employment ┆ ['lanier   ┆ ['lanier  ┆ 29        │
# │ 0009501440 ┆ Worldwide, ┆ -00-001606 ┆     ┆   ┆            ┆ worldwide  ┆ worldwide ┆           │
# │ 0001606..0 ┆ Inc. /     ┆ -d3.html   ┆     ┆   ┆            ┆ inc']      ┆ inc']     ┆           │
# │ …          ┆ Exhib…     ┆            ┆     ┆   ┆            ┆            ┆           ┆           │
# │ 731190..00 ┆ PHILIP STR ┆ 0000950132 ┆ 106 ┆ … ┆ employment ┆ ['philip   ┆ ['philip  ┆ 106       │
# │ 0095013200 ┆ AWBRIDGE   ┆ -00-000238 ┆     ┆   ┆            ┆ strawbridg ┆ o strawbr ┆           │
# │ 000238..00 ┆ CONTRACT   ┆ -d11.html  ┆     ┆   ┆            ┆ e', 'it    ┆ idge',    ┆           │
# │ …          ┆ TE…        ┆            ┆     ┆   ┆            ┆ cor…       ┆ 'it c…    ┆           │
# │ 912093..00 ┆ Merger     ┆ 0000912093 ┆ 166 ┆ … ┆ purchase&m ┆ ['e-tek    ┆ ['rainbow ┆ 166       │
# │ 0091209300 ┆            ┆ -00-000004 ┆     ┆   ┆ a          ┆ dynamics   ┆ acquisiti ┆           │
# │ 000004..00 ┆            ┆ -d4.html   ┆     ┆   ┆            ┆ inc', 'jds ┆ on inc',  ┆           │
# │ …          ┆            ┆            ┆     ┆   ┆            ┆ un…        ┆ 'e…       ┆           │
# │            ┆            ┆            ┆     ┆   ┆            ┆            ┆           ┆           │
# │            ┆            ┆            ┆     ┆   ┆            ┆            ┆           ┆           │
# │            ┆ AGREEMENT  ┆            ┆     ┆   ┆            ┆            ┆           ┆           │
# │            ┆ AND PLAN…  ┆            ┆     ┆   ┆            ┆            ┆           ┆           │
# │ 1026869..0 ┆ PARTNERSHI ┆ 0001026869 ┆ 19  ┆ … ┆ services&s ┆ ['hca',    ┆ ['hyundai ┆ 19        │
# │ 0010268690 ┆ P TERMINAT ┆ -00-000003 ┆     ┆   ┆ upply      ┆ 'independe ┆ capital   ┆           │
# │ 0000003..0 ┆ ION        ┆ -d13.html  ┆     ┆   ┆            ┆ nt energy  ┆ america', ┆           │
# │ …          ┆ AGREEM…    ┆            ┆     ┆   ┆            ┆ op…        ┆ 'h…       ┆           │
# │ 731190..00 ┆ IT CORPORA ┆ 0000950132 ┆ 104 ┆ … ┆ employment ┆ ['it group ┆ ['it      ┆ 104       │
# │ 0095013200 ┆ TION RESTO ┆ -00-000238 ┆     ┆   ┆            ┆ inc']      ┆ group     ┆           │
# │ 000238..00 ┆ RATION     ┆ -d9.html   ┆     ┆   ┆            ┆            ┆ inc']     ┆           │
# │ …          ┆ PLA…       ┆            ┆     ┆   ┆            ┆            ┆           ┆           │
# └────────────┴────────────┴────────────┴─────┴───┴────────────┴────────────┴───────────┴───────────┘

# %% [markdown]
# ## Matching these companies with their headquarters

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("peopledatalabssf/free-7-million-company-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /Users/georgia/.cache/kagglehub/datasets/peopledatalabssf/free-7-million-company-dataset/versions/1

# %%
#load in the kaggle dataset
local_path = '/Users/georgia/.cache/kagglehub/datasets/peopledatalabssf/free-7-million-company-dataset/versions/1/companies_sorted.csv'
companies_df = pl.read_csv(local_path)

# %%
companies_df
# Out:
# shape: (7_173_426, 11)
# ┌─────────┬────────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │         ┆ name       ┆ domain    ┆ year      ┆ … ┆ country   ┆ linkedin  ┆ current   ┆ total     │
# │ ---     ┆ ---        ┆ ---       ┆ founded   ┆   ┆ ---       ┆ url       ┆ employee  ┆ employee  │
# │ i64     ┆ str        ┆ str       ┆ ---       ┆   ┆ str       ┆ ---       ┆ estimate  ┆ estimate  │
# │         ┆            ┆           ┆ f64       ┆   ┆           ┆ str       ┆ ---       ┆ ---       │
# │         ┆            ┆           ┆           ┆   ┆           ┆           ┆ i64       ┆ i64       │
# ╞═════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 5872184 ┆ ibm        ┆ ibm.com   ┆ 1911.0    ┆ … ┆ united    ┆ linkedin. ┆ 274047    ┆ 716906    │
# │         ┆            ┆           ┆           ┆   ┆ states    ┆ com/compa ┆           ┆           │
# │         ┆            ┆           ┆           ┆   ┆           ┆ ny/ibm    ┆           ┆           │
# │ 4425416 ┆ tata consu ┆ tcs.com   ┆ 1968.0    ┆ … ┆ india     ┆ linkedin. ┆ 190771    ┆ 341369    │
# │         ┆ ltancy     ┆           ┆           ┆   ┆           ┆ com/compa ┆           ┆           │
# │         ┆ services   ┆           ┆           ┆   ┆           ┆ ny/tata-c ┆           ┆           │
# │         ┆            ┆           ┆           ┆   ┆           ┆ ons…      ┆           ┆           │
# │ 21074   ┆ accenture  ┆ accenture ┆ 1989.0    ┆ … ┆ ireland   ┆ linkedin. ┆ 190689    ┆ 455768    │
# │         ┆            ┆ .com      ┆           ┆   ┆           ┆ com/compa ┆           ┆           │
# │         ┆            ┆           ┆           ┆   ┆           ┆ ny/accent ┆           ┆           │
# │         ┆            ┆           ┆           ┆   ┆           ┆ ure       ┆           ┆           │
────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
# See how many master_parties in df_combined have a fuzzy match with any company in companies_df["name"]

# Get unique company names and master parties, dropping nulls
company_names = companies_df["name"].unique().drop_nulls().to_list()
# Flatten the list of lists in master_parties, drop nulls, and get unique
master_parties = (
    pl.Series([p for sublist in df_combined["master_parties"].drop_nulls().to_list() for p in (sublist if isinstance(sublist, list) else [sublist])])
    .unique()
    .drop_nulls()
    .to_list()
)
print(len(master_parties))
print(master_parties)
# Out:
# 137
# ["['centra software inc']", "['com inc', 'michael t devlin', 'rational software corporation', 'devclick']", "['dakota growers pasta co inc', 'american community bank', 'alta california bank', 'atlantic capital bancshares inc', 'american community bancshares inc', 'acb']", "['clubcorp inc']", "['w andb', 'conwell corporation', 'ffe transportation services inc', 'w and b refrigeration service company', 'ffe inc', 'frozen food express industries inc', 'frozen food express inc', 'lisa motor lines inc']", "['q comm international inc']", "['ensco offshore company', 'ensco international inc', 'secretary of transportation', 'tdi halter l', 'friede goldman offshore texas']", "['rainbow acquisition inc', 'e-tek dynamics inc', 'jds uniphase corporation']", "['north shore gas co il']", "['philip o strawbridge', 'it corporation', 'it group inc']", "['moto photo inc', 'paul pieschel']", "['credit suisse first boston', 'cibc world markets corp one world financial center new york', 'protein design labs inc de', 'warburg dillon read llc', 'cowen securities corporation']", "['beneco enterprises inc', 'ohm corporation', 'it group inc', 'it corporation', 'ohm remediation services corp', 'fleet national bank', 'citicorp usa inc']", "['stockwalk com group inc', 'robert j vosburgh']", "['keycorp leasing', 'it group inc', 'it corporation', 'key corporate capital inc']", "['hartford steam company', 'ctg resources inc', 'independent energy operations inc', 'downtown cogeneration associates']", "['portola packaging inc', 'sand hill systems inc', 'shs b', 'portola company iv llc']", "['merix corporation', 'merix corp', 'merix merix', 'deborah a coleman']", "['william v ehlen', 'valley national corporation', 'valle de oro bank na', 'community first bancshares inc']", "['connecticut natural gas corporation', 'energy east corporation', 'ctg resources inc', 'oak merger co']", "['cpac inc']", "['shoreline financial corporation', 'wayne r koebel', 'shoreline bank']", "['wells fargo business credit', 'rockshox inc']", "['community first bancshares inc', 'river bancorp inc']", "['rational software corporation', 'paul d levy']", "['merrill corporation network composition', 'matrix pharmaceutical inc de']", "['hyundai capital america', 'hca', 'independent energy operations inc', 'halpern capital advisors', 'paul romanelli', 'hitachi capital america corp', 'the energy network inc', 'ctg resources inc', 'ten']", "['middleby corp', 'wachovia bank national association', 'the middleby corporation']", "['albert t potas', 'old kent financial corp mi', 'richard a mcgarrity', 'janet s nisbett']", "['community first bancshares inc', 'donald r mengedoth']", "['william p crawford', 'john d boyles', 'old kent financial corp mi', 'william g gonzalez', 'fred p keller', 'michael j jandernoa', 'richard l antonini', 'james p hackett', 'kevin t kabat', 'erina hanka', 'richard m devos jr']", "['8x8 inc']", "['preview systems inc']", "['stanlee p greene jr', 'steven d crandall', 'ronald c mishler', 'joseph t keating', 'old kent financial corp mi', 'larry s magnesen', 'mary ellen baker', 'gregory k daniels', 'donald r britton', 'gary s bernard', 'david adams']", "['com inc', 'rational software corporation', 'devclick', 'paul d levy']", "['it group inc', 'general electric capital corporation']", "['us bank national association', 'marten transport ltd']", "['lanier worldwide inc']", "['c r bard inc', 'bard c r inc nj']", "['lcnb corp', 'dakin insurance agency inc', 'dakin acquisition corporation']", "['merix corporation', 'merix corp', 'daniel t olson']", "['connecticut natural gas corporation', 'ctg resources inc']", "['theragenics corp']", "['moto photo inc', 'fuji photo film usa inc']", "['mdecd', 'mississippi department of economic and community development', 'mississippi major economic impact authority', 'wellman inc', 'mississippi business finance corporation', 'wellman of mississippi inc']", "['john c van leeuwen glens falls national bank', 'jack', 'arrow financial corporation', ' ...

# %%
def search_company_matches(search_name, companies_df, fuzzy_threshold=80):
    # Exact match
    exact_matches = companies_df.filter(pl.col("name") == search_name)
    if exact_matches.height > 0:
        print("Exact match:")
        print(exact_matches)
        print(f"Number of exact matches: {exact_matches.height}")
        return {
            "exact": exact_matches,
            "substring": None,
            "fuzzy": None
        }

    # Substring/contain match (case-insensitive)
    contain_matches = companies_df.filter(
        pl.col("name").str.to_lowercase().str.contains(search_name.lower())
    )
    if contain_matches.height > 0:
        print("\nContain (substring) match:")
        print(contain_matches)
        print(f"Number of substring matches: {contain_matches.height}")
        return {
            "exact": None,
            "substring": contain_matches,
            "fuzzy": None
        }

    # Fuzzy match (using token_sort_ratio)
    company_names = companies_df["name"].unique().drop_nulls().to_list()
    fuzzy_match, score, idx = process.extractOne(search_name, company_names, scorer=fuzz.token_sort_ratio)
    print(f"\nBest fuzzy match: {fuzzy_match} (score: {score})")
    fuzzy_matches_df = None
    fuzzy_count = 0
    if score >= fuzzy_threshold:
        fuzzy_matches_df = companies_df.filter(pl.col("name") == fuzzy_match)
        print(fuzzy_matches_df)
        fuzzy_count = fuzzy_matches_df.height
    print(f"Number of fuzzy matches (above threshold): {fuzzy_count}")

    return {
        "exact": None,
        "substring": None,
        "fuzzy": {
            "match": fuzzy_match,
            "score": score,
            "df": fuzzy_matches_df
        }
    }

# %%
result = search_company_matches("fifth third", companies_df)
# Out:
# Exact match:
# shape: (1, 11)
# ┌─────────┬───────┬────────┬─────────┬───┬─────────┬──────────────────┬──────────┬─────────────────┐
# │         ┆ name  ┆ domain ┆ year    ┆ … ┆ country ┆ linkedin url     ┆ current  ┆ total employee  │
# │ ---     ┆ ---   ┆ ---    ┆ founded ┆   ┆ ---     ┆ ---              ┆ employee ┆ estimate        │
# │ i64     ┆ str   ┆ str    ┆ ---     ┆   ┆ str     ┆ str              ┆ estimate ┆ ---             │
# │         ┆       ┆        ┆ f64     ┆   ┆         ┆                  ┆ ---      ┆ i64             │
# │         ┆       ┆        ┆         ┆   ┆         ┆                  ┆ i64      ┆                 │
# ╞═════════╪═══════╪════════╪═════════╪═══╪═════════╪══════════════════╪══════════╪═════════════════╡
# │ 2291055 ┆ fifth ┆ null   ┆ 1858.0  ┆ … ┆ united  ┆ linkedin.com/com ┆ 43       ┆ 63              │
# │         ┆ third ┆        ┆         ┆   ┆ states  ┆ pany/fifth-thi…  ┆          ┆                 │
# └─────────┴───────┴────────┴─────────┴───┴─────────┴──────────────────┴──────────┴─────────────────┘
# Number of exact matches: 1

# %%
_ = search_company_matches("zamba corp", companies_df)
# Out:
# Contain (substring) match:
# shape: (1, 11)
# ┌─────────┬────────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │         ┆ name       ┆ domain    ┆ year      ┆ … ┆ country   ┆ linkedin  ┆ current   ┆ total     │
# │ ---     ┆ ---        ┆ ---       ┆ founded   ┆   ┆ ---       ┆ url       ┆ employee  ┆ employee  │
# │ i64     ┆ str        ┆ str       ┆ ---       ┆   ┆ str       ┆ ---       ┆ estimate  ┆ estimate  │
# │         ┆            ┆           ┆ f64       ┆   ┆           ┆ str       ┆ ---       ┆ ---       │
# │         ┆            ┆           ┆           ┆   ┆           ┆           ┆ i64       ┆ i64       │
# ╞═════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 5393610 ┆ zamba corp ┆ zambasolu ┆ null      ┆ … ┆ united    ┆ linkedin. ┆ 0         ┆ 3         │
# │         ┆ oration    ┆ tions.com ┆           ┆   ┆ states    ┆ com/compa ┆           ┆           │
# │         ┆            ┆           ┆           ┆   ┆           ┆ ny/zamba- ┆           ┆           │
# │         ┆            ┆           ┆           ┆   ┆           ┆ cor…      ┆           ┆           │
# └─────────┴────────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘
# Number of substring matches: 1

# %%
_ = search_company_matches("wta campbell technology park", companies_df)
# Out:
# Best fuzzy match: canberra technology park (score: 76.92307692307692)
# Number of fuzzy matches (above threshold): 0

# %%
df_combined
# Out:
# shape: (172, 28)
# ┌────────────┬────────────┬────────────┬─────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ title      ┆ text       ┆ short_titl ┆     ┆ … ┆ agreement_ ┆ parties_cl ┆ master_pa ┆ metadata_ │
# │ ---        ┆ ---        ┆ e          ┆ --- ┆   ┆ type       ┆ eaned      ┆ rties     ┆ idx       │
# │ str        ┆ str        ┆ ---        ┆ i64 ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---       │
# │            ┆            ┆ str        ┆     ┆   ┆ str        ┆ str        ┆ str       ┆ i64       │
# ╞════════════╪════════════╪════════════╪═════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ 823534..00 ┆ EX10.14    ┆ 0000823534 ┆ 145 ┆ … ┆ employment ┆ ['repap    ┆ ['repap   ┆ 145       │
# │ 0082353400 ┆            ┆ -00-000004 ┆     ┆   ┆            ┆ enterprise ┆ enterpris ┆           │
# │ 000004..00 ┆            ┆ -d7.html   ┆     ┆   ┆            ┆ s inc',    ┆ es inc',  ┆           │
# │ …          ┆            ┆            ┆     ┆   ┆            ┆ 'ste…      ┆ 'ste…     ┆           │
# │            ┆            ┆            ┆     ┆   ┆            ┆            ┆           ┆           │
# │            ┆ EXHIBIT    ┆            ┆     ┆   ┆            ┆            ┆           ┆           │
# │            ┆ 10.14      ┆            ┆     ┆   ┆            ┆            ┆           ┆           │
# │            ┆ EMPL…      ┆            ┆     ┆   ┆            ┆            ┆           ┆           │
# │ 39273..000 ┆ EXHIBIT    ┆ 0000039273 ┆ 67  ┆ … ┆ security   ┆ ['w andb', ┆ ['w       ┆ 67        │
# │ 0039273000 ┆ 10.1       ┆ -00-000005 ┆     ┆   ┆            ┆ 'conwell   ┆ andb',    ┆           │
# │ 00005..000 ┆            ┆ -d2.html   ┆     ┆   ┆            ┆ corporatio ┆ 'conwell  ┆           │
# │ …          ┆ &nbsp;&nbs ┆            ┆     ┆   ┆            ┆ …          ┆ corporati ┆           │
# │            ┆ p;&nbs…    ┆            ┆     ┆   ┆            ┆            ┆ o…        ┆           │
# │ 929455..00 ┆ EXHIBIT    ┆ 0000929455 ┆ 175 ┆ … ┆ na         ┆ ['clubcorp ┆ ['clubcor ┆ 175       │
# │ 0092945500 ┆ 10.20      ┆ -00-000002 ┆     ┆   ┆            ┆ inc']      ┆ p inc']   ┆           │
# │ 000002..00 ┆ NEITHER    ┆ -d14.pdf   ┆     ┆   ┆            ┆            ┆           ┆           │
# │ …          ┆ THIS WAR…  ┆            ┆     ┆   ┆            ┆            ┆           ┆           │
# │ 716399..00 ┆ Prepared   ┆ 0000912057 ┆ 78  ┆ … ┆ shareholde ┆ ['calendar ┆ ['calenda ┆ 78        │
# │ 0091205700 ┆ by MERRILL ┆ -00-004404 ┆     ┆   ┆ r          ┆ capital    ┆ r capital ┆           │
# │ 004404..00 ┆ CORPORATIO ┆ -d2.html   ┆     ┆   ┆            ┆ inc',      ┆ inc',     ┆           │
# │ …          ┆ …          ┆            ┆     ┆   ┆            ┆ 'entr…     ┆ 'entr…    ┆           │
# │ 731190..00 ┆ FORM OF    ┆ 0000950132 ┆ 107 ┆ … ┆ employment ┆ ['the it   ┆ ['it      ┆ 107       │
# │ 0095013200 ┆ BONUS      ┆ -00-000238 ┆     ┆   ┆            ┆ group      ┆ group     ┆           │
# │ 000238..00 ┆ AGREEMENT  ┆ -d12.html  ┆     ┆   ┆            ┆ inc', 'it  ┆ inc']     ┆           │
# │ …          ┆            ┆            ┆     ┆   ┆            ┆ group…     ┆           ┆           │
# │            ┆            ┆            ┆     ┆   ┆            ┆            ┆           ┆           │
# │            ┆   Ex…      ┆            ┆     ┆   ┆            ┆            ┆           ┆           │
# │ …          ┆ …          ┆ …          ┆ …   ┆ … ┆ …          ┆ …          ┆ …         ┆ …         │
# │ 1089786..0 ┆ Lanier     ┆ 0000950144 ┆ 29  ┆ … ┆ employment ┆ ['lanier   ┆ ['lanier  ┆ 29        │
# │ 0009501440 ┆ Worldwide, ┆ -00-001606 ┆     ┆   ┆            ┆ worldwide  ┆ worldwide ┆           │
# │ 0001606..0 ┆ Inc. /     ┆ -d3.html   ┆     ┆   ┆            ┆ inc']      ┆ inc']     ┆           │
# │ …          ┆ Exhib…     ┆            ┆     ┆   ┆            ┆            ┆           ┆           │
# │ 731190..00 ┆ PHILIP STR ┆ 0000950132 ┆ 106 ┆ … ┆ employment ┆ ['philip   ┆ ['philip  ┆ 106       │
# │ 0095013200 ┆ AWBRIDGE   ┆ -00-000238 ┆     ┆   ┆            ┆ strawbridg ┆ o strawbr ┆           │
# │ 000238..00 ┆ CONTRACT   ┆ -d11.html  ┆     ┆   ┆            ┆ e', 'it    ┆ idge',    ┆           │
# │ …          ┆ TE…        ┆            ┆     ┆   ┆            ┆ cor…       ┆ 'it c…    ┆           │
# │ 912093..00 ┆ Merger     ┆ 0000912093 ┆ 166 ┆ … ┆ purchase&m ┆ ['e-tek    ┆ ['rainbow ┆ 166       │
# │ 0091209300 ┆            ┆ -00-000004 ┆     ┆   ┆ a          ┆ dynamics   ┆ acquisiti ┆           │
# │ 000004..00 ┆            ┆ -d4.html   ┆     ┆   ┆            ┆ inc', 'jds ┆ on inc',  ┆           │
# │ …          ┆            ┆            ┆     ┆   ┆            ┆ un…        ┆ 'e…       ┆           │
# │            ┆            ┆            ┆     ┆   ┆            ┆            ┆           ┆           │
# │            ┆            ┆            ┆     ┆   ┆            ┆            ┆           ┆           │
# │            ┆ AGREEMENT  ┆            ┆     ┆   ┆            ┆            ┆           ┆           │
# │            ┆ AND PLAN…  ┆            ┆     ┆   ┆            ┆            ┆           ┆           │
# │ 1026869..0 ┆ PARTNERSHI ┆ 0001026869 ┆ 19  ┆ … ┆ services&s ┆ ['hca',    ┆ ['hyundai ┆ 19        │
# │ 0010268690 ┆ P TERMINAT ┆ -00-000003 ┆     ┆   ┆ upply      ┆ 'independe ┆ capital   ┆           │
# │ 0000003..0 ┆ ION        ┆ -d13.html  ┆     ┆   ┆            ┆ nt energy  ┆ america', ┆           │
# │ …          ┆ AGREEM…    ┆            ┆     ┆   ┆            ┆ op…        ┆ 'h…       ┆           │
# │ 731190..00 ┆ IT CORPORA ┆ 0000950132 ┆ 104 ┆ … ┆ employment ┆ ['it group ┆ ['it      ┆ 104       │
# │ 0095013200 ┆ TION RESTO ┆ -00-000238 ┆     ┆   ┆            ┆ inc']      ┆ group     ┆           │
# │ 000238..00 ┆ RATION     ┆ -d9.html   ┆     ┆   ┆            ┆            ┆ inc']     ┆           │
# │ …          ┆ PLA…       ┆            ┆     ┆   ┆            ┆            ┆           ┆           │
# └────────────┴────────────┴────────────┴─────┴───┴────────────┴────────────┴───────────┴───────────┘

# %%
import ast

# master_parties is a list of strings like "['bristol hotels and resorts', 'jeffrey p mayer']"
# We want to flatten it into a list of all entities, splitting on commas inside the lists

flat_master_parties = []
for entry in master_parties:
    # Safely evaluate the string to a Python list
    try:
        entities = ast.literal_eval(entry)
        if isinstance(entities, list):
            flat_master_parties.extend([e.strip() for e in entities])
        else:
            # If not a list, just add the string itself
            flat_master_parties.append(str(entities).strip())
    except Exception:
        # If parsing fails, fallback to splitting on comma
        flat_master_parties.extend([e.strip(" '") for e in entry.split(",") if e.strip(" '")])

flat_master_parties
# Out:
# ['centra software inc',
#  'com inc',
#  'michael t devlin',
#  'rational software corporation',
#  'devclick',
#  'dakota growers pasta co inc',
#  'american community bank',
#  'alta california bank',
#  'atlantic capital bancshares inc',
#  'american community bancshares inc',
#  'acb',
#  'clubcorp inc',
#  'w andb',
#  'conwell corporation',
#  'ffe transportation services inc',
#  'w and b refrigeration service company',
#  'ffe inc',
#  'frozen food express industries inc',
#  'frozen food express inc',
#  'lisa motor lines inc',
#  'q comm international inc',
#  'ensco offshore company',
#  'ensco international inc',
#  'secretary of transportation',
#  'tdi halter l',
#  'friede goldman offshore texas',
#  'rainbow acquisition inc',
#  'e-tek dynamics inc',
#  'jds uniphase corporation',
#  'north shore gas co il',
#  'philip o strawbridge',
#  'it corporation',
#  'it group inc',
#  'moto photo inc',
#  'paul pieschel',
#  'credit suisse first boston',
#  'cibc world markets corp one world financial center new york',
#  'protein design labs inc de',
#  'warburg dillon read llc',
#  'cowen securities corporation',
#  'beneco enterprises inc',
#  'ohm corporation',
#  'it group inc',
#  'it corporation',
#  'ohm remediation services corp',
#  'fleet national bank',
#  'citicorp usa inc',
#  'stockwalk com group inc',
#  'robert j vosburgh',
#  'keycorp leasing',
#  'it group inc',
#  'it corporation',
#  'key corporate capital inc',
#  'hartford steam company',
#  'ctg resources inc',
#  'independent energy operations inc',
#  'downtown cogeneration associates',
#  'portola packaging inc',
#  'sand hill systems inc',
#  'shs b',
#  'portola company iv llc',
#  'merix corporation',
#  'merix corp',
#  'merix merix',
#  'deborah a coleman',
#  'william v ehlen',
#  'valley national corporation',
#  'valle de oro bank na',
#  'community first bancshares inc',
#  'connecticut natural gas corporation',
#  'energy east corporation',
#  'ctg resources inc',
#  'oak merger co',
#  'cpac inc',
#  'shoreline financial corporation',
#  'wayne r koebel',
#  'shoreline bank',
#  'wells fargo business credit',
#  'rockshox inc',
#  'community first bancshares inc',
#  'river bancorp inc',
#  'rational software corporation',
#  'paul d levy',
#  'merrill corporation network composition',
#  'matrix pharmaceutical inc de',
#  'hyundai capital america',
#  'hca',
#  'independent energy operations inc',
#  'halpern capital advisors',
#  'paul romanelli',
#  'hitachi capital america corp',
#  'the energy network inc',
#  'ctg resources inc',
#  'ten',
#  'middleby corp',
#  'wachovia bank national association',
#  'the middleby corporation',
#  'albert t potas',
#  'old kent financial corp mi',
#  'richard a mcgarrity',
#  'janet s nisbett',
#  'community first bancshares inc',
#  'donald r mengedoth',
#  'william p crawford',
#  'john d boyles',
#  'old kent financial corp mi',
#  'william g gonzalez',
#  'fred p keller',
#  'michael j jandernoa',
#  'richard l antonini',
#  'james p hackett',
#  'kevin t kabat',
#  'erina hanka',
#  'richard m devos jr',
#  '8x8 inc',
#  'preview systems inc',
#  'stanlee p greene jr',
#  'steven d crandall',
#  'ronald c mishler',
#  'joseph t keating',
#  'old kent financial corp mi',
#  'larry s magnesen',
#  'mary ellen baker',
#  'gregory k daniels',
#  'donald r britton',
#  'gary s bernard',
#  'david adams',
#  'com inc',
#  'rational software corporation',
#  'devclick',
#  'paul d levy',
#  'it group inc',
#  'general electric capital corporation',
#  'us bank national association',
#  'marten transport ltd',
#  'lanier worldwide inc',
#  'c r bard inc',
#  'bard c r inc nj',
#  'lcnb corp',
#  'dakin insurance agency inc',
#  'dakin acquisition corporation',
#  'merix corporation',
#  'merix corp',
#  'daniel t olson',
#  'connecticut natural gas corporation',
#  'ctg resources inc',
#  'theragenics corp',
#  'moto photo inc',
#  'fuji photo film usa inc',
#  'mdecd',
#  'mississippi department of economic and community development',
#  'mississippi major economic impact authority',
#  'wellman inc',
#  'mississippi business finance corporation',
#  'wellman of mississippi inc',
#  'john c van leeuwen glens falls national bank',
#  'jack',
#  'arrow financial corporation',
#  'trust company',
#  'protective life annuity insurance co',
#  'protective life insurance company',
#  'american foundation life insurance company',
#  'merix corporation',
#  'merix corp',
#  'dan olson',
#  'preview systems inc',
#  'preview software inc',
#  'limar realty corp',
#  'q comm international inc',
#  'highland ranch inc',
#  'mcms inc',
#  'e-tek dynamics inc',
#  'jds uniphase corporation',
#  'rainbow acquisition inc',
#  'jdsu',
#  'global crossing usa inc',
#  'exodus communications inc',
#  'community first bancshares inc',
#  'enron north america corp',
#  'north shore gas company',
#  'north shore gas co il',
#  'tellabs inc',
#  'rational software corporation',
#  'adc telecommunications inc',
#  'melvin r heier',
#  'donna mae heier',
#  'scientific technologies inc',
#  'psi-tronix technologies inc',
#  'psi-tronix inc',
#  'tobacco business',
#  'dimon incorporated',
#  'albert c monk iii',
#  'dimon inc',
#  'portola packaging inc',
#  'sand hill systems inc',
#  'e-tek dynamics inc',
#  'jds uniphase corporation',
#  'chyron corp',
#  'amsouth bank',
#  'chyron corporation',
#  'louis a dubrow',
#  'geoffrey b bloom',
#  'william jb brown',
#  'wolverine world wide inc de',
#  'steven m duffy',
#  'v dean estes',
#  'owen s baxter',
#  'richard c deblasio',
#  'arthur g croci',
#  'etec systems inc',
#  'applied materials inc de',
#  'boston acquisition sub inc',
#  'it group inc',
#  'the vaughn group ltd',
#  'esterline technologies corporation',
#  'autozone inc',
#  'arrow financial corporation',
#  'michael f massiano',
#  'merrill corporation network',
#  'adobe systems inc',
#  'com inc',
#  'devclick',
#  'rational software corporation',
#  'paul levy',
#  'harold s stephen',
#  'repap enterprises inc',
#  'stephen capital inc',
#  'com inc',
#  'paul d levy paul d levy',
#  'rational software corporation',
#  'devclick',
#  'merrill corporation network composition',
#  'adobe systems inc',
#  'stockwalk com group inc',
#  'william yang',
#  'stockwalkcom inc',
#  'm-one investment securities inc',
#  'state national bancshares inc lubbock',
#  'newco',
#  'bankshares inc abilene',
#  'independent bankshares inc',
#  'rockshox inc',
#  'bryan l kelln',
#  'old kent financial corp mi',
#  'q comm international inc',
#  'azore acquisition corporation',
#  'chemical financial corporation',
#  'thomas l hoy',
#  'arrow financial corporation',
#  'glens falls national bank',
#  'trust company',
#  'us bank national association',
#  'norstan inc',
#  'ten',
#  'the energy network inc',
#  'hartford steam company',
#  'ctg resources inc',
#  'downtown cogeneration associates',
#  'q comm international inc',
#  'stephen c flaherty',
#  'ryland group inc',
#  'kilroy realty lp',
#  'ing',
#  'portola packaging inc',
#  'portola company iv llc',
#  'service provider',
#  'arrow financial corporation',
#  'ryland group inc',
#  'zamba corp',
#  'wta campbell technology park llc',
#  'zamba corporation',
#  'congress financial corporation',
#  'huffy corp',
#  'it group inc',
#  'community first bancshares inc',
#  'william ehlen',
#  'valle de oro bank na',
#  'richard rowe',
#  'ronnie way saratoga',
#  'mcms inc',
#  'the chase manhattan bank',
#  'arrow financial corporation',
#  'john j murphy',
#  'arrow financial corporation',
#  'glens falls national bank',
#  'trust company',
#  'citibank na',
#  'govco',
#  'citibank international plc',
#  'citicorp north america inc',
#  'ensco international inc',
#  'etec systems inc',
#  'applied materials inc de',
#  'parent boston acquisition sub inc',
#  'huffy corp',
#  'keybank national association',
#  'washington inventory service',
#  'bank one',
#  'bank of america na',
#  'huffy corporation',
#  'fifth third bank',
#  'american sports design company',
#  'huffy service first inc',
#  'royce union bicycle company',
#  'national city bank',
#  'the prudential insurance company of america',
#  'inland real estate investment corporation',
#  'the inland property management group inc',
#  'inland real estate advisory services inc',
#  'inland commercial property management inc',
#  'inland advisors inc',
#  'inland management',
#  'inland real estate corporation',
#  'the inland group inc',
#  'yahoo inc',
#  'manhattan bank',
#  'bank of america na',
#  'banc of america securities llc',
#  'citibank',
#  'compaq computer corporation',
#  'mark f furlong',
#  'old kent financial corp mi',
#  'michelle l van dyke',
#  'david wagner',
#  'kevin t kabat',
#  'kenneth c krei',
#  'james a hubbard',
#  'robert h warrington',
#  'david c schneider',
#  'etec systems inc',
#  'grantee boston acquisition sub inc',
#  'applied materials inc de',
#  'ensco international inc',
#  'hastings manufacturing co',
#  'portola packaging inc',
#  'bristol hotels and resorts',
#  'jeffrey p mayer',
#  'repap marketing inc',
#  'repap enterprises inc',
#  'stephen c larson',
#  'neil falco',
#  'asset holdings company vi llc',
#  'selco service corporation',
#  'huffy corp',
#  'keybank national association',
#  'bank of america na',
#  'fifth third bank',
#  'bank one na',
#  'national city bank',
#  'the prudential insurance company of america',
#  'enron north america corp',
#  'north shore gas co il',
#  'the peoples gas light and coke company',
#  'jds uniphase corporation',
#  'jds uniphase acquisition inc',
#  'epitaxx inc',
#  'calendar capital inc',
#  'entrenaut inc',
#  'sunrise medical inc',
#  'telident inc',
#  'teltronics inc',
#  'gerard r bilodeau glens falls national bank',
#  'gerry',
#  'arrow financial corporation',
#  'trust company',
#  'north shore gas co il',
#  'peoples energy corporation',
#  'bergen brunswig corporation',
#  'wachovia bank national association',
#  'blue hill inc',
#  'blue ridge asset funding corporation',
#  'bergen brunswig drug company',
#  'w e cantrell',
#  'lanier worldwide inc',
#  'p m anderson',
#  'v m arthur',
#  'b r bergin',
#  'q comm international inc',
#  'gem investments ltd',
#  'qcom',
#  'gem global yield fund',
#  'loughran and co',
#  'huffy corp',
#  'washington inventory service',
#  'hcac inc',
#  'huffy sports inc',
#  'huffy risk management inc',
#  'huffy corporation',
#  'congress financial corporation',
#  'huffy service first inc',
#  'james r mahoney',
#  'it group inc',
#  'it corporation',
#  'shoreline financial corporation',
#  'moto photo inc',
#  'provident bank',
#  'ensco offshore company',
#  'ensco international inc',
#  'bankers trust company',
#  'sunrise medical inc',
#  'mike',
#  'michael hammes',
#  'chemical financial corporation',
#  'chemical bank',
#  'mr ott',
#  'alan w ott',
#  'trust company',
#  'graham freeman',
#  'adobe systems inc',
#  'jann margaret freeman',
#  'csb bancorp inc oh',
#  'moto photo inc',
#  'frank m montano',
#  'chyron corp',
#  'roger henderson',
#  'pro-bel limited',
#  'chyron corporation',
#  'david a mason',
#  'moto photo inc',
#  'jonathan f file',
#  'fuji photo film usa inc',
#  'repap enterprises inc',
#  'stephen c larson',
#  'terry w mcbride',
#  'glenbrae management services limited',
#  'adobe systems europe limited',
#  'derek j gray',
#  'adobe systems inc',
#  'connecticut natural gas corporation',
#  'cole national group inc',
#  'corning natural gas corporation',
#  'cng',
#  'ctg resources inc',
#  'the chase manhattan bank',
#  'protein design labs inc de',
#  'trust company national association',
#  'reuters group plc',
#  'pricewaterhousecoopers chartered accountants and registered auditors',
#  'mike',
#  'fda',
#  'future developments america inc',
#  'michael casey',
#  'matrix pharmaceutical inc de']

# %%
len(flat_master_parties)
# Out:
# 443

# %%
# only keep unique master parties 
flat_master_parties = list(set(flat_master_parties))
len(flat_master_parties)
# Out:
# 316

# %%
# Commented out because it takes too long to run
# # Go through all names in df_combined and perform matching, storing results

# results = []

# for search_name in flat_master_parties:
#     match_result = search_company_matches(search_name, companies_df)
#     # Try exact match first
#     if match_result["exact"] is not None and match_result["exact"].height > 0:
#         best_match_name = match_result["exact"]["name"][0]
#         score = 100
#     # Then substring match
#     elif match_result["substring"] is not None and match_result["substring"].height > 0:
#         best_match_name = match_result["substring"]["name"][0]
#         score = 100
#     # Then fuzzy match
#     elif match_result["fuzzy"] is not None and match_result["fuzzy"]["score"] >= 0:
#         best_match_name = match_result["fuzzy"]["match"]
#         score = match_result["fuzzy"]["score"]
#     else:
#         best_match_name = "NO MATCH"
#         score = None
#     print(f"Search name: {search_name}, Best match name: {best_match_name}, Score: {score}")
#     results.append({
#         "df_combined_name": search_name,
#         "best_match_name": best_match_name,
#         "fuzzy_score": score
#     })

# # Convert results to a DataFrame
# match_results_df = pl.DataFrame(results)

# %%
match_results_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 match_results_df
#
# NameError: name 'match_results_df' is not defined

# %% [markdown]
# Now I need to heal the ones that are clearly incorrect one by one

# %%
#first let's split those that have a score of 100. Those should be okay to trust. 
rows_100 = []
for row in match_results_df.iter_rows(named=True):
    if row["fuzzy_score"] == 100:
        rows_100.append(row)
df_100 = pl.DataFrame(rows_100)

# %%
import pandas as pd

pdf = df_100.to_pandas()
pd.set_option("display.max_colwidth", None)  # don't truncate
print(pdf.to_string())
# Out:
#                                df_combined_name                                        best_match_name  fuzzy_score
# 0                   compaq computer corporation                            compaq computer corporation        100.0
# 1                                           acb                                                    acb        100.0
# 2                                           ing                                                    ing        100.0
# 3                inland real estate corporation                         inland real estate corporation        100.0
# 4                              service provider                                       service provider        100.0
# 5                                       com inc        bet (bet networks, a subsidiary of viacom inc.)        100.0
# 6                                           fda                                                    fda        100.0
# 7   the prudential insurance company of america  the prudential insurance company of america, pru-care        100.0
# 8                                      cpac inc                                              cpac inc.        100.0
# 9                   scientific technologies inc                 chrysalis scientific technologies inc.        100.0
# 10               chemical financial corporation                         chemical financial corporation        100.0
# 11                      north shore gas company                                north shore gas company        100.0
# 12                                trust company                                          trust company        100.0
# 13                    glens falls national bank                  glens falls national bank & trust co.        100.0
# 14                                   zamba corp                                      zamba corporation        100.0
# 15                                     citibank                                               citibank        100.0
# 16                  bergen brunswig corporation                            bergen brunswig corporation        100.0
# 17                                chemical bank                                          chemical bank        100.0
# 18                                michael casey                             michael casey & associates        100.0
# 19                    key corporate capital inc                              key corporate capital inc        100.0
# 20                                  david adams                                    david adamson group        100.0
# 21    inland real estate investment corporation              inland real estate investment corporation        100.0
# 22                                        gerry                                                  gerry        100.0
# 23                      american community bank                                american community bank        100.0
# 24                                     bank one                                               bank one        100.0
# 25                            inland management                                      inland management        100.0
# 26                         marten transport ltd                                   marten transport ltd        100.0
# 27                                         jack                                                   jack        100.0
# 28                                 clubcorp inc                                           clubcorp inc        100.0
# 29                                        newco                                                  newco        100.0
# 30                                          cng                                                    cng        100.0
# 31                                  wellman inc                                            wellman inc        100.0
# 32                                          hca                                                    hca        100.0
# 33                                middleby corp                               the middleby corporation        100.0
# 34       the peoples gas light and coke company                 the peoples gas light and coke company        100.0
# 35                                 david wagner                                           david wagner        100.0
# 36                      hyundai capital america                                hyundai capital america        100.0
# 37                                    yahoo inc                               eyipee, inc / yahoo inc.        100.0
# 38                                         jdsu                                                   jdsu        100.0
# 39                               provident bank                                         provident bank        100.0
# 40                             ryland group inc                                       ryland group inc        100.0
# 41                            huffy corporation                                      huffy corporation        100.0
# 42                             etec systems inc                                   sharetec systems inc        100.0
# 43                            adobe systems inc                             adobe systems incorporated        100.0
# 44                   credit suisse first boston                             credit suisse first boston        100.0
# 45                   citicorp north america inc                             citicorp north america inc        100.0
# 46                 washington inventory service                           washington inventory service        100.0
# 47                                   huffy corp                                             huffy corp        100.0
# 48                     the middleby corporation                               the middleby corporation        100.0
# 49                                          ten                                                    ten        100.0
# 50                                 amsouth bank                                           amsouth bank        100.0
# 51                            reuters group plc                                      reuters group plc        100.0
# 52                               it corporation                                         it corporation        100.0
# 53                                 it group inc                           commercial credit group inc.        100.0
# 54                                        govco                                          govconnection        100.0
# 55                      global crossing usa inc                                global crossing usa inc        100.0
# 56                     the chase manhattan bank                               the chase manhattan bank        100.0
# 57           trust company national association            bessemer trust company national association        100.0
# 58                                         qcom                                               qcom spa        100.0
# 59                            merix corporation                                      merix corporation        100.0
# 60                                 autozone inc                                           autozone inc        100.0
# 61                                   merix corp                                      merix corporation        100.0
# 62                                  norstan inc                                            norstan inc        100.0
# 63                 hitachi capital america corp                          hitachi capital america corp.        100.0
# 64                                      ffe inc                                               ffe inc.        100.0
# 65                             fifth third bank                                       fifth third bank        100.0
# 66                               shoreline bank                                         shoreline bank        100.0
# 67                           national city bank                                     national city bank        100.0
# 68                          fleet national bank                                    fleet national bank        100.0
# 69                                  chyron corp                                     chyron corporation        100.0
# 70                            zamba corporation                                      zamba corporation        100.0
# 71                             theragenics corp                                theragenics corporation        100.0
# 72                               manhattan bank                               the chase manhattan bank        100.0
# 73                              ohm corporation                              w kreykenbohm corporation        100.0
# 74                           chyron corporation                                     chyron corporation        100.0
# 75                                         mike                                                   mike        100.0
# 76                         lisa motor lines inc                                   lisa motor lines inc        100.0
# 77                                        shs b                                shs burridge architects        100.0
# 78                        bankers trust company                                  bankers trust company        100.0

# %% [markdown]
# 100s that are incorrect: com_inc, scientific technologies inc, michael casey, david adams, etec systems inc, it group inc, govco, trust company national association, ohm corporation, manhattan bank
#
# non_100s that are incorrect: boston acquisition sub inc, us bank national association, merix merix, the inland group inc, calendar capital inc, dakin acquisition corporation, huffy service first inc, john c van leeuwen glens falls national bank, ensco offshore company, american sports design company, william v ehlen, frank m montano, stanlee p greene jr, citibank international plc, michael hammes, jds uniphase corporation, paul d levy, bryan l kelln, tdi halter l, william g gonzalez, w e cantrell, kevin t kabat, valle de oro bank na, selco service, q comm international, frozen food express industries inc, stephen c flaherty, wachovia bank national association, william yang, teltronics inc, mary ellen baker, michael j jandernoa, shoreline financial corporation, john d boyles, hartford steam, louis a dubrow, inland commercial property management inc, dan olson, terry w mcrbide, paul pieschel, dimon incorporated, philip o strawbridge, mdecd, paul levy, gem investments ltd, alan w ott, applied materials inc de, tellabs, bard c r inc, mcms, thomas l hoy, daniel t olson, merrill corporation network, owen s baxter, gregory k daniels, huffy risk management inc, hcac inc, albert c monk, albert t potas, adc telecommunications inc, wayne r koebel, congress financial corporation, john j murphy, blue hill inc, c r bard inc, downtown cogeneration associates, repap enterprises inc, m-one investment securities, royce union bicycle company, paul d levy paul d levy, adobe systems europe limited, gem global yield fund, robert j vosburgh, wells fargo business credit, halpern capital advisors, blue ridge asset funding corporation, inland advisors, roger, paul romanelli, software corporation international, mr ott, gary s bernard, ronald c mishler, road master inc, cibc world markets corp one world financial center new york, stephen capital inc, steven m duffy, stockwalkcom inc, graham, kilroy realty lp, keybank national association, inland real estate advisory services inc, richard c deblasio, glenbrae management services limited, general electric capital corporation, david c schneider, stephen c larson, melvin r heier, donald r britton, w and b refrigeration service company, mississippi department of economic and community development, river bancorp inc, energy east corporation

# %%
possible_companies = companies_df["name"].to_list()
unique_possible_companies = list(set(possible_companies))

# %%
#let's try a different approach. Instead of fuzzy matching, I want to give a list of 
# the possible options to an LLM and then see which one they think is the closest match. 
# If it isn't 100% sure, give three options and I can choose

def message(possible_companies, single_company):
    messages = [
        {
            "role": "system",
            "content": "You are an expert in corporate accounting and reporting. We want to match company names between two lists."
        },
        {
            "role": "user",
            "content": f"Here's the list of all the possible companies: {possible_companies}. This is the single company: {single_company}. Please tell me which one of the first companies best matches. If you aren't super confident, you can give me three options. Return your answer in this JSON format: {{\"match\": \"Company Name[s]\", \"confidence\": \"Confidence Level\"}}"}
    ]
    
    return messages

# %%
from openai import OpenAI

client = OpenAI(
    api_key=os.getenv("OPENROUTER_API_KEY"), 
    base_url = "https://openrouter.ai/api/v1"
)

# %%
from sentence_transformers import SentenceTransformer
from tqdm import tqdm

model = SentenceTransformer("all-MiniLM-L6-v2")

# Embed with progress bar
all_text_embeddings = []
for company in tqdm(unique_possible_companies, desc="Embedding possible companies"):
    all_text_embeddings.append(model.encode(company, convert_to_tensor=True))

single_company_embeddings = []
for party in tqdm(flat_master_parties, desc="Embedding master parties"):
    single_company_embeddings.append(model.encode(party, convert_to_tensor=True))
# Out:
# Embedding possible companies:   2%|▏         | 165448/7004635 [14:26:03<34083:29:22, 17.94s/it]IOStream.flush timed out

# %%
response = client.chat.completions.create(
    model="deepseek/deepseek-r1-0528-qwen3-8b:free", 
    messages= messages,
    temperature=0.1,
    max_tokens=1000
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 response = client.chat.completions.create(
#       2     model="deepseek/deepseek-r1-0528-qwen3-8b:free",
#       3     messages= messages,
#       4     temperature=0.1,
#       5     max_tokens=1000
#       6 )
#
# File ~/Library/Caches/pypoetry/virtualenvs/tclp-NuG6qVAh-py3.10/lib/python3.10/site-packages/openai/_utils/_utils.py:275, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     273             msg = f"Missing required argument: {quote(missing[0])}"
#     274     raise TypeError(msg)
# --> 275 return func(*args, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/tclp-NuG6qVAh-py3.10/lib/python3.10/site-packages/openai/resources/chat/completions.py:829, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     788 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     789 def create(
#     790     self,
#    (...)
#     826     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     827 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     828     validate_response_format(response_format)
# --> 829     return self._post(
#     830         "/chat/completions",
#     831         body=maybe_transform(
#     832             {
#     833                 "messages": messages,
#     834                 "model": model,
#     835                 "audio": audio,
#     836                 "frequency_penalty": frequency_penalty,
#     837                 "function_call": function_call,
#     838                 "functions": functions,
#     839                 "logit_bias": logit_bias,
#     840                 "logprobs": logprobs,
#     841                 "max_completion_tokens": max_completion_tokens,
#     842                 "max_tokens": max_tokens,
#     843                 "metadata": metadata,
#     844                 "modalities": modalities,
#     845                 "n": n,
#     846                 "parallel_tool_calls": parallel_tool_calls,
#     847                 "prediction": prediction,
#     848                 "presence_penalty": presence_penalty,
#     849                 "response_format": response_format,
#     850                 "seed": seed,
#     851                 "service_tier": service_tier,
#     852                 "stop": stop,
#     853                 "store": store,
#     854                 "stream": stream,
#     855                 "stream_options": stream_options,
#     856                 "temperature": temperature,
#     857                 "tool_choice": tool_choice,
#     858                 "tools": tools,
#     859                 "top_logprobs": top_logprobs,
#     860                 "top_p": top_p,
#     861                 "user": user,
#     862             },
#     863             completion_create_params.CompletionCreateParams,
#     864         ),
#     865         options=make_request_options(
#     866             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     867         ),
#     868         cast_to=ChatCompletion,
#     869         stream=stream or False,
#     870         stream_cls=Stream[ChatCompletionChunk],
#     871     )
#
# File ~/Library/Caches/pypoetry/virtualenvs/tclp-NuG6qVAh-py3.10/lib/python3.10/site-packages/openai/_base_client.py:1278, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1264 def post(
#    1265     self,
#    1266     path: str,
#    (...)
#    1273     stream_cls: type[_StreamT] | None = None,
#    1274 ) -> ResponseT | _StreamT:
#    1275     opts = FinalRequestOptions.construct(
#    1276         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1277     )
# -> 1278     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Library/Caches/pypoetry/virtualenvs/tclp-NuG6qVAh-py3.10/lib/python3.10/site-packages/openai/_base_client.py:955, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     952 else:
#     953     retries_taken = 0
# --> 955 return self._request(
#     956     cast_to=cast_to,
#     957     options=options,
#     958     stream=stream,
#     959     stream_cls=stream_cls,
#     960     retries_taken=retries_taken,
#     961 )
#
# File ~/Library/Caches/pypoetry/virtualenvs/tclp-NuG6qVAh-py3.10/lib/python3.10/site-packages/openai/_base_client.py:1044, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1042 if remaining_retries > 0 and self._should_retry(err.response):
#    1043     err.response.close()
# -> 1044     return self._retry_request(
#    1045         input_options,
#    1046         cast_to,
#    1047         retries_taken=retries_taken,
#    1048         response_headers=err.response.headers,
#    1049         stream=stream,
#    1050         stream_cls=stream_cls,
#    1051     )
#    1053 # If the response is streamed then we need to explicitly read the response
#    1054 # to completion before attempting to access the response text.
#    1055 if not err.response.is_closed:
#
# File ~/Library/Caches/pypoetry/virtualenvs/tclp-NuG6qVAh-py3.10/lib/python3.10/site-packages/openai/_base_client.py:1093, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1089 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1090 # different thread if necessary.
#    1091 time.sleep(timeout)
# -> 1093 return self._request(
#    1094     options=options,
#    1095     cast_to=cast_to,
#    1096     retries_taken=retries_taken + 1,
#    1097     stream=stream,
#    1098     stream_cls=stream_cls,
#    1099 )
#
# File ~/Library/Caches/pypoetry/virtualenvs/tclp-NuG6qVAh-py3.10/lib/python3.10/site-packages/openai/_base_client.py:991, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     988 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     990 try:
# --> 991     response = self._client.send(
#     992         request,
#     993         stream=stream or self._should_stream_response_body(request=request),
#     994         **kwargs,
#     995     )
#     996 except httpx.TimeoutException as err:
#     997     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~/Library/Caches/pypoetry/virtualenvs/tclp-NuG6qVAh-py3.10/lib/python3.10/site-packages/httpx/_client.py:926, in Client.send(self, request, stream, auth, follow_redirects)
#     922 self._set_timeout(request)
#     924 auth = self._build_request_auth(request, auth)
# --> 926 response = self._send_handling_auth(
#     927     request,
#     928     auth=auth,
#     929     follow_redirects=follow_redirects,
#     930     history=[],
#     931 )
#     932 try:
#     933     if not stream:
#
# File ~/Library/Caches/pypoetry/virtualenvs/tclp-NuG6qVAh-py3.10/lib/python3.10/site-packages/httpx/_client.py:954, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     951 request = next(auth_flow)
#     953 while True:
# --> 954     response = self._send_handling_redirects(
#     955         request,
#     956         follow_redirects=follow_redirects,
#     957         history=history,
#     958     )
#     959     try:
#     960         try:
#
# File ~/Library/Caches/pypoetry/virtualenvs/tclp-NuG6qVAh-py3.10/lib/python3.10/site-packages/httpx/_client.py:991, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     988 for hook in self._event_hooks["request"]:
#     989     hook(request)
# --> 991 response = self._send_single_request(request)
#     992 try:
#     993     for hook in self._event_hooks["response"]:
#
# File ~/Library/Caches/pypoetry/virtualenvs/tclp-NuG6qVAh-py3.10/lib/python3.10/site-packages/httpx/_client.py:1027, in Client._send_single_request(self, request)
#    1022     raise RuntimeError(
#    1023         "Attempted to send an async request with a sync Client instance."
#    1024     )
#    1026 with request_context(request=request):
# -> 1027     response = transport.handle_request(request)
#    1029 assert isinstance(response.stream, SyncByteStream)
#    1031 response.request = request
#
# File ~/Library/Caches/pypoetry/virtualenvs/tclp-NuG6qVAh-py3.10/lib/python3.10/site-packages/httpx/_transports/default.py:236, in HTTPTransport.handle_request(self, request)
#     223 req = httpcore.Request(
#     224     method=request.method,
#     225     url=httpcore.URL(
#    (...)
#     233     extensions=request.extensions,
#     234 )
#     235 with map_httpcore_exceptions():
# --> 236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#     240 return Response(
#     241     status_code=resp.status,
#     242     headers=resp.headers,
#     243     stream=ResponseStream(resp.stream),
#     244     extensions=resp.extensions,
#     245 )
#
# File ~/Library/Caches/pypoetry/virtualenvs/tclp-NuG6qVAh-py3.10/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/Library/Caches/pypoetry/virtualenvs/tclp-NuG6qVAh-py3.10/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/Library/Caches/pypoetry/virtualenvs/tclp-NuG6qVAh-py3.10/lib/python3.10/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/Library/Caches/pypoetry/virtualenvs/tclp-NuG6qVAh-py3.10/lib/python3.10/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/Library/Caches/pypoetry/virtualenvs/tclp-NuG6qVAh-py3.10/lib/python3.10/site-packages/httpcore/_sync/http11.py:88, in HTTP11Connection.handle_request(self, request)
#      86         self._send_request_headers(**kwargs)
#      87     with Trace("send_request_body", logger, request, kwargs) as trace:
# ---> 88         self._send_request_body(**kwargs)
#      89 except WriteError:
#      90     # If we get a write error while we're writing the request,
#      91     # then we supress this error and move on to attempting to
#      92     # read the response. Servers can sometimes close the request
#      93     # pre-emptively and then respond with a well formed HTTP
#      94     # error response.
#      95     pass
#
# File ~/Library/Caches/pypoetry/virtualenvs/tclp-NuG6qVAh-py3.10/lib/python3.10/site-packages/httpcore/_sync/http11.py:159, in HTTP11Connection._send_request_body(self, request)
#     157 for chunk in request.stream:
#     158     event = h11.Data(data=chunk)
# --> 159     self._send_event(event, timeout=timeout)
#     161 self._send_event(h11.EndOfMessage(), timeout=timeout)
#
# File ~/Library/Caches/pypoetry/virtualenvs/tclp-NuG6qVAh-py3.10/lib/python3.10/site-packages/httpcore/_sync/http11.py:166, in HTTP11Connection._send_event(self, event, timeout)
#     164 bytes_to_send = self._h11_state.send(event)
#     165 if bytes_to_send is not None:
# --> 166     self._network_stream.write(bytes_to_send, timeout=timeout)
#
# File ~/Library/Caches/pypoetry/virtualenvs/tclp-NuG6qVAh-py3.10/lib/python3.10/site-packages/httpcore/_backends/sync.py:138, in SyncStream.write(self, buffer, timeout)
#     136 while buffer:
#     137     self._sock.settimeout(timeout)
# --> 138     n = self._sock.send(buffer)
#     139     buffer = buffer[n:]
#
# File ~/.pyenv/versions/3.10.15/lib/python3.10/ssl.py:1239, in SSLSocket.send(self, data, flags)
#    1235     if flags != 0:
#    1236         raise ValueError(
#    1237             "non-zero flags not allowed in calls to send() on %s" %
#    1238             self.__class__)
# -> 1239     return self._sslobj.write(data)
#    1240 else:
#    1241     return super().send(data, flags)
#
# KeyboardInterrupt:

# %%
assistant_reply_1 = response.choices[0].message.content
